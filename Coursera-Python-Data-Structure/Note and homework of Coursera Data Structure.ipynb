# %% [markdown]
# ### [Coursera Data structure](https://www.coursera.org/learn/python-data/lecture/ViAEF/8-3-lists-and-strings)

# %%
import numpy as np
import pandas as pd

# %%
DATAFILE='beatles-diskography.csv'

# %%
def parse_file(datafile):
    data=[]
    with open(datafile,'rb')as f:
        header=f.readline().split(',')
        counter=0
        for line in f:
            if counter==10:
                break
            fields=line.split(',')
            entry={}
            
            for i,value in enumerate(fields):
                entry[header[i].strip()]=value.strip()
            data.append(entry)
            counter+=1
    return data

# %%
parse_file(DATAFILE)
# Out:
# [{'BPI Certification': 'Gold',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Platinum',
#   'Released': '22 March 1963',
#   'Title': 'Please Please Me',
#   'UK Chart Position': '1',
#   'US Chart Position': '-'},
#  {'BPI Certification': 'Platinum',
#   'Label': 'Parlophone(UK)',
#   'RIAA Certification': 'Gold',
#   'Released': '22 November 1963',
#   'Title': 'With the Beatles',
#   'UK Chart Position': '1',
#   'US Chart Position': '-'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(CAN)',
#   'RIAA Certification': '',
#   'Released': '25 November 1963',
#   'Title': 'Beatlemania! With the Beatles',
#   'UK Chart Position': '-',
#   'US Chart Position': '-'},
#  {'BPI Certification': '',
#   'Label': 'Vee-Jay(US)',
#   'RIAA Certification': '',
#   'Released': '10 January 1964',
#   'Title': 'Introducing... The Beatles',
#   'UK Chart Position': '-',
#   'US Chart Position': '2'},
#  {'BPI Certification': '',
#   'Label': 'Capitol(US)',
# ...

# %%
import os
import pprint
import csv

# %%
DATADIR=''
def parse_csv(datafile):
    data=[]
    n=0
    with open(datafile,'rb')as sd:
        r=csv.DictReader(sd)
        for line in r:
            data.append(line)
    return data

if _name_=='_main_':
    datafile=os.path.join(DATADIR,DATAFILE)
    parse_csv(datafile)
    d=parse_csv(datafile)
    pprint.pprint(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e087ba2c45ab> in <module>()
#       9     return data
#      10
# ---> 11 if _name_=='_main_':
#      12     datafile=os.path.join(DATADIR,DATAFILE)
#      13     parse_csv(datafile)
#
# NameError: name '_name_' is not defined

# %%
import os

DATADIR = ""
DATAFILE = "beatles-diskography.csv"


def parse_file(datafile):
    data = []
    with open(datafile, "r") as f:
        for line in f:
            print line

    return data


def test():
    # a simple test of your implemetation
    datafile = os.path.join(DATADIR, DATAFILE)
    d = parse_file(datafile)
    firstline = {'Title': 'Please Please Me', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '22 March 1963', 'US Chart Position': '-', 'RIAA Certification': 'Platinum', 'BPI Certification': 'Gold'}
    tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}

    assert d[0] == firstline
    assert d[9] == tenthline

    
test()

# %%
#new line character
# \n : this stars a new line
#new line is one character
# new line is white space

# %%
#How to read files in python

# %%
xfile=open('mbox.txt')
for cheese in xfile:
    print(cheese)

# %%
fhand=open('mbox.txt')
count=0
for line in fhand:
    count =count+1
print('Line Count:',count)

# %%
fhand=open('mbox-short.txt')
inp=fhand.read()# read the intire file
print(len(inp))

# %%
fhand=open('mbox.txt')
for line in fhand:
    if line.startwith('From'):
        print(line)

# %%
#print statement writes a new line 
#how to deal with this
#use rstrip

# %%
fhand=open('mbox-short.txt')
for line in fhand:
    line=line.rstrip()#get away with all the blank space
    if line.startswith('From:'):
        print(line)
#same as:
for line in fhand:
    line=line.rstrip()
    if not line.startwith('From:'):
        continue
    print(line)

# %% [markdown]
# ### using input to open a new file

# %%
fname=input('Enter the file name :')
fhand=open(fname)
count=0
for line in fhand:
    if line.startwith('Subject:'):
        count=count+1
print('There were',count,'subject line in ',fname)

# %%
fname=input('Enter the filename: ')
try:
    fhand=open(fname)
except:
    print('File cannot be opened:',fname)#to avoid times when it cannot be opend
    quit()
count=0
for line in fhand:
    if line.startwith('Subject:'):
        count=count+1
print('There were',count,'subject lines in ',fname)

# %% [markdown]
# #### Write a program that prompts for a file name, then opens that file and reads through the file, and print the contents of the file in upper case. Use the file words.txt to produce the output below.

# %%
fname = input("Enter file name: ")
fh = open(fname)

for line in fh:
    print(line.rstrip().upper())

# %%
fname = raw_input("Enter file name: ")
if len(fname) == 0:
    fname = 'mbox-short.txt'
fh = open(fname)
count = 0
tot = 0
ans = 0
for line in fh:
    if not line.startswith("X-DSPAM-Confidence:") : continue
    count = count + 1
    num = float(line[21:])
    tot = num + tot
ans = tot / count
print "Average spam confidence:", ans

# %%
for friend in friends:
    print('Happy',friend)
    #equally: 
for i in range(len(friends)):
    friend=friends[i]
    print('Happy New Year:',friend)

# %%
stuff=list()
stuff.append('book')
stuff.append(99)
print(stuff)
# Out:
# ['book', 99]

# %%
some=[9,1,21]
9 in some
# Out:
# True

# %%
20 not in some
# Out:
# True

# %%
some.sort()

# %%
some
# Out:
# [1, 9, 21]

# %%
numlist=list()
while True:
    inp=input('Enter a number: ')
    if inp == 'done': break
    value =float(inp)
    numlist.append(value)
average=sum(numlist)/len(numlist)
print('Average:',average)
# Out:
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 'done'
# ('Average:', 2.0)

# %%
#or using this:
total=0
count=0
while True:
    inp=input('Enter a number: ')
    if inp =='done': break
    value=float(inp)
    total=total+value
    count=count+1
average=total/count
print('Average:',average)
# Out:
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 'done'
# ('Average:', 2.5)

# %%
# best friend: Stirngs and lists

# %%
abc='With three words'
stuff=abc.split()
print(stuff)
# Out:
# ['With', 'three', 'words']

# %%
for w in stuff:
    print(w)
# Out:
# With
# three
# words

# %%
line='a lot of    spaces'
ect=line.split()
print(ect)
# Out:
# ['a', 'lot', 'of', 'spaces']

# %%
line='first;second;third'
thing=line.split(';')
print(thing)
print(len(thing))
# Out:
# ['first', 'second', 'third']
# 3

# %%
fhand=open('mbox-short.txt')
for line in fhand:
    line=line.rstrip()
    if not line.startwith('From'):continue
    words=line.split()
    print(words[2])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-37c454c5e62f> in <module>()
# ----> 1 fhand=open('mbox-short.txt')
#       2 for line in fhand:
#       3     line=line.rstrip()
#       4     if not line.startwith('From'):continue
#       5     words=line.split()
#
# IOError: [Errno 2] No such file or directory: 'mbox-short.txt'

# %%
words='From stephen@umd.edu 123 five'
pic=words.split()
print(pic)
print(pic[1])
p=pic[1].split('@')
print(p)
print(p[1])
# Out:
# ['From', 'stephen@umd.edu', '123', 'five']
# stephen@umd.edu
# ['stephen', 'umd.edu']
# umd.edu

# %%
#8.4 Open the file romeo.txt and read it line by line. For each line, 
#split the line into a list of words using the split() method. 
#The program should build a list of words. For each word on each line check to see 
#if the word is already in the list and if not append it to the list.

# %%
fname = input("Enter file name: ")
fh fname = raw_input("Enter file name: ")
counter = 0
fh = open(fname)

for line in fh :
    line = line.rstrip()
    if not line.startswith('From '): continue        
    words = line.split()
    print words[1]
    counter +=1

print "There were", counter, "lines in the file with From as the first word"= open(fname)
lst = list()
for line in fh:
    word=line.rstrip().split()
    for element in word:
        if  element in lst:
            continue
        else:
            lst.append(element)
lst.sort()
print(lst)

# %%
fname = input("Enter file name: ")
if len(fname) < 1 : fname = "mbox-short.txt"

fh = open(fname)
count = 0
for line in fh:
    line.rstrip()
    if not line.startswith('From') and line.startswith("From:"): continue
    linesp=line.split()[1]
    print(linesp)
    count=count+1


print("There were", count, "lines in the file with From as the first word")

# %%
file_name = raw_input("Enter a file name: ")
lines = [line.strip("\n") for line in open(file_name, 'r')
         if line.startswith("From") and not line.startswith("From:")]

count = 0
for line in lines:
    words = line.split()
    print words[1]
    count += 1
print "There were %s lines in the file with From as the first word" % count

# %%
#DICTIONARY

# %%
purse=dict()

# %%
purse['money']=12
purse['candy']=14
purse['tissues']=75

# %%
purse
# Out:
# {'candy': 14, 'money': 12, 'tissues': 75}

# %%
purse['candy']=15#dictionary can be changed

# %%
purse
# Out:
# {'candy': 15, 'money': 12, 'tissues': 75}

# %%
lst=list()
lst.append(21)
lst.append(34)
print(lst)
# Out:
# [21, 34]

# %%
#counting with dictionary

# %%
'money' in purse
# Out:
# True

# %%
names=['csv','sss','ddf','cfdf','csv','sss','csv']
counts=dict()

# %%
for name in names:
    if name not in counts:
        counts[name]=1
    else:
        counts[name]=counts[name]+1
print(counts)
# Out:
# {'cfdf': 1, 'csv': 3, 'ddf': 1, 'sss': 2}

# %%
counts=dict()
names=['csv','sss','ddf','cfdf','csv','sss','sss']
for name in names:
    counts[name]=counts.get(name,0)+1# 0 means default value here
print(counts)
# Out:
# {'cfdf': 1, 'csv': 2, 'ddf': 1, 'sss': 3}

# %%
#count words practice

# %%
counts=dict()
print('Enter a line of text')
line=input('')
words=line.split()
print('Words:',words)
print('counting...')
for word in words:
    counts[word]= counts.get(word,0)+1
print('Counts:',counts)
# Out:
# Enter a line of text
# 'cool a a line interesting'
# ('Words:', ['cool', 'a', 'a', 'line', 'interesting'])
# counting...
# ('Counts:', {'a': 2, 'interesting': 1, 'line': 1, 'cool': 1})

# %%
# use for loop to go through dictionary

# %%
counts
# Out:
# {'a': 2, 'cool': 1, 'interesting': 1, 'line': 1}

# %%
for key in counts:
    print(key,counts[key])
# Out:
# ('a', 2)
# ('interesting', 1)
# ('line', 1)
# ('cool', 1)

# %%
list(counts)#keys
# Out:
# ['a', 'interesting', 'line', 'cool']

# %%
counts.keys()
# Out:
# ['a', 'interesting', 'line', 'cool']

# %%
counts.values()
# Out:
# [2, 1, 1, 1]

# %%
counts.items()#get pair
# Out:
# [('a', 2), ('interesting', 1), ('line', 1), ('cool', 1)]

# %%
for k,v in counts.items():
    print(k,v)
# Out:
# ('a', 2)
# ('interesting', 1)
# ('line', 1)
# ('cool', 1)

# %%
name=input('Enter file:')
handle=open(name)
counts=dict()#count use dict()#word list use list 
for line in handle:
    words=line.split()
    for word in words:
        counts[word]=counts.get(word,0)+1
print(counts)
#what is the largest one
bigcount=None
bigword=None
for word,count in counts.items():
    if bigcount is None or count>bigcount:
        bigword=word
        bigword=count
print(bigword,bigcount)

# %%
name = raw_input("Enter file:")
if len(name) < 1 : name = "mbox-short.txt"
handle = open(name)
#text = handle.read()
#words = text.split()

words = list()

for line in handle:
    if not line.startswith("From:") : continue
    line = line.split()
    words.append(line[1])


counts = dict()

for word in words:
           counts[word] = counts.get(word, 0) + 1 
#best way to count
maxval = None
maxkey = None
for key,val in counts.items() :
#   if maxval == None : maxval = val
  if maxval == None or val > maxval:
      maxval = val
      maxkey = key   

print maxkey, maxval

# %%
name = input("Enter file:")
if len(name) < 1 : name = "mbox-short.txt"
handle = open(name)

words = list()
counts = list()
for line in handle:
    if not line.startswith("From:") : continue
    line = line.split()
    words.append(line[1])
    for word in words:
        counts[word]=counts.get(word,0)+1
print(counts)
#what is the largest one
bigcount=None
bigword=None
for word,count in counts.items():
    if bigcount is None or count>bigcount:
        bigword=word
        bigword=count
print(bigword,bigcount)

# %%
#fname=input('Enter File: ')
#if len(fname)<1: fname='clown.txt'#nothing input then input this
hand=open('Q3_Text.txt')
di=dict()
for lin in hand:
    lin=lin.rstrip()
    print(lin)
    wds=lin.split()
    print(wds)
    for w in wds:
        if w in di:
            di[w]=di[w]+1
            print('existing')
        else:
            di[w]=1
            print('**new**')
        print(w,di[w])
# Out:
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly normal, thank you very much. They were the last people you'd expect to be involved in anything strange or mysterious, because they just didn't hold with such nonsense.
# ['Mr.', 'and', 'Mrs.', 'Dursley,', 'of', 'number', 'four,', 'Privet', 'Drive,', 'were', 'proud', 'to', 'say', 'that', 'they', 'were', 'perfectly', 'normal,', 'thank', 'you', 'very', 'much.', 'They', 'were', 'the', 'last', 'people', "you'd", 'expect', 'to', 'be', 'involved', 'in', 'anything', 'strange', 'or', 'mysterious,', 'because', 'they', 'just', "didn't", 'hold', 'with', 'such', 'nonsense.']
# **new**
# ('Mr.', 1)
# **new**
# ('and', 1)
# **new**
# ('Mrs.', 1)
# **new**
# ('Dursley,', 1)
# **new**
# ('of', 1)
# **new**
# ('number', 1)
# **new**
# ('four,', 1)
# **new**
# ('Privet', 1)
# **new**
# ('Drive,', 1)
# **new**
# ('were', 1)
# **new**
# ('proud', 1)
# **new**
# ('to', 1)
# **new**
# ('say', 1)
# **new**
# ...

# %% [markdown]
# ### Tuples

# %%
#tuples are like list.#immutable
#string are immutable

# %%
names=['csv','sss','ddf','cfdf','csv','sss','csv']

# %%
l=list()
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__name__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'get_ipython',
#  'l',
#  'names',
#  'quit']

# %%
t=tuple()
dir(t)#only count,index
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
(x,y)=(4,'fred')
print(y)#corresponding assignment
# Out:
# fred

# %%
(a,b,c)=(99,98,101)
print(c)
# Out:
# 101

# %%
#comparing tuples

# %%
(0,1,2)<(5,1,2)
# Out:
# True

# %%
(0,1,2)<(0,1,2)
# Out:
# False

# %%
(1,1,5,6)<(1,1,6,5)#from first pair and then go next
# Out:
# True

# %%
d={'a':10,'b':1,'c':22}
d.items()
# Out:
# [('a', 10), ('c', 22), ('b', 1)]

# %%
s=sorted(d.items())#sorted only sorted on the keys

# %%
for k,v in s:
    print(k,v)
# Out:
# ('a', 10)
# ('b', 1)
# ('c', 22)

# %%
#how to sort by values

# %%
tmp=list()
for k,v in d.items():
    tmp.append((v,k))

# %%
print(tmp)
# Out:
# [(10, 'a'), (22, 'c'), (1, 'b')]

# %%
tmp=sorted(tmp,reverse=True)#list can be sorted

# %%
print(tmp)
# Out:
# [(22, 'c'), (10, 'a'), (1, 'b')]

# %%
# ten most common words in the text

# %%
fhnad=open('romeo.txt')
counts=dict()
for line in fhand:
    words=line.split()
    for word in words:
        counts[word]=counts.get(word,0)+1
lst=list()
for key,val in counts.items():
    newtup=(val,key)
    lst.append(newtup)
lst=sorted(lst,reverse=True)
for val ,key in lst[:10]:
    print(key,val)

# %%
#only one line of code

# %%
c={'a':10,'b':1,'c':22}

# %%
print(sorted([(v,k) for k,v in c.items()]))#one line of code
# Out:
# [(1, 'b'), (10, 'a'), (22, 'c')]

# %%
#list comprehension

# %%
name = input("Enter file:")
if len(name) < 1 : name = "mbox-short.txt"
handle = open(name)
counts=dict()
for line in handle:
    if line.startswith("From "):
        time = line.split()[5].split(":")
        counts[time[0]] = counts.get(time[0], 0) + 1

list = list()
for key, value in counts.items():
    list.append( (key,value) )
list.sort()

for val ,key in list:
    print(val,key)
